# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjanamaharana/1-backend-project/blob/main/task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Q1.
# Create a list of 5 student names and display all the names.

students = ["Sanjana", "Priya", "Anjali", "Riya", "Pooja"]
print(students)

# %%
#  Q2.
# Create a list of 5 numbers and display:
# - First element
# - Last element

numbers = [10, 20, 30, 40, 50]

print("First element:", numbers[0])
print("Last element:", numbers[-1])

# %%
# Q3.
# Create a list of fruits. Add a new fruit using append() and display the updated list.

fruits = ["Apple", "Banana", "Mango"]

fruits.append("Orange")

print(fruits)

# %%
# Q4.
# Create a list of subjects. Insert "AI" at the third position and display the updated list.

subjects = ["Math", "Science", "English", "Computer"]

subjects.insert(2, "AI")

print(subjects)

# %%
# Q5.
# Create a list of 5 numbers. Remove the third element and display the updated list.
numbers = [10, 20, 30, 40, 50]
numbers.pop(2)
print(numbers)

# %%
# Q6.
# Create a list:
# [10, 20, 30, 40, 50]
# Display:
# - Length of the list
# - Maximum value
# - Minimum value
# - Sum of all elements

numbers = [10, 20, 30, 40, 50]

print("Length:", len(numbers))
print("Maximum:", max(numbers))
print("Minimum:", min(numbers))
print("Sum:", sum(numbers))

# %%
# Q7.
# Take 5 numbers from the user and store them in a list. Display the complete list.

numbers = []

for i in range(5):
    num = int(input("Enter a number: "))
    numbers.append(num)

print("List:", numbers)

# %%
# Q8.
# Create a list of cities and check whether "Delhi" exists in the list or not.

cities = ["Mumbai", "Delhi", "Kolkata", "Chennai"]

if "Delhi" in cities:
    print("Delhi exists in the list")
else:
    print("Delhi does not exist in the list")

# %%
# Q9.
# Create a tuple containing 5 colors and display all the colors.

colors = ("Red", "Blue", "Green", "Yellow", "Pink")

print(colors)

# %%
# Q10.
# Create a tuple:
# (10, 20, 30, 40, 50)
# Display:
# - First element
# - Last element

numbers = (10, 20, 30, 40, 50)

print("First element:", numbers[0])
print("Last element:", numbers[-1])

# %%
# Q11.
# Create a tuple of student names and count how many times a particular name appears.

students = ("Sanjana", "Priya", "Riya", "Sanjana", "Anjali")

print("Sanjana appears", students.count("Sanjana"), "times")

# %%
# Q12.
# Create a tuple of numbers and display:
# - Maximum value
# - Minimum value
# - Length of the tuple

numbers = (10, 20, 30, 40, 50)

print("Maximum:", max(numbers))
print("Minimum:", min(numbers))
print("Length:", len(numbers))

# %%
# Q13.
# Create a tuple and try to modify one value. Observe the error and write your observation.

numbers = (10, 20, 30)

numbers[1] = 50

# %%
# Q14.
# Convert the following tuple into a list and display the result:
# (1, 2, 3, 4, 5)

t = (1, 2, 3, 4, 5)
lst = list(t)
print(lst)

# %%
# Q15.
# Create a set:
# {10, 20, 30, 40, 50}
# Display the set.

numbers = {10, 20, 30, 40, 50}
print(numbers)

# %%
#  Q16.

# Create a set:
# {10, 20, 30}
# Add 40 and display the updated set.

numbers = {10, 20, 30}
numbers.add(40)
print(numbers)

# %%
# Q17.
# Create a set:
# {10, 20, 30, 40}
# Remove 20 and display the updated set.

numbers = {10, 20, 30, 40}
numbers.remove(20)
print(numbers)

# %%
# Q18.
# Create a set:
# {10, 20, 30, 30, 40, 40}
# Display the output and explain why duplicate values are removed.

numbers = {10, 20, 30, 30, 40, 40}
print(numbers)

# %%
# Q19.
# Create two sets:
# A = {1, 2, 3, 4}
# B = {3, 4, 5, 6}

# Display:
# - Union
# - Intersection

A = {1, 2, 3, 4}
B = {3, 4, 5, 6}

print("Union:", A.union(B))
print("Intersection:", A.intersection(B))

# %%
# Q20.
# Take a number from the user and check whether it exists in a set or not.

numbers = {10, 20, 30, 40, 50}

num = int(input("Enter a number: "))

if num in numbers:
    print("Number exists in the set")
else:
    print("Number does not exist in the set")

# %%
# Q21.
# Create a dictionary containing:
# - Name
# - Age
# - City
# Display all the values.

person = {
    "Name": "Sanjana",
    "Age": 22,
    "City": "Rourkela"
}

print(person.values())

# %%
# Q22.
# Create a student dictionary:
# {
# "name":"Siva",
# "age":24
# }
# Add:
# "course":"Python"
# Display the updated dictionary.

student = {
    "name": "Siva",
    "age": 24
}

student["course"] = "Python"

print(student)

# %%
# Q23.
# Create a dictionary of employee details and display:
# - All Keys
# - All Values

employee = {
    "id": 101,
    "name": "Rahul",
    "salary": 50000
}

print("Keys:", employee.keys())
print("Values:", employee.values())

# %%
#  Q24.
# Create a dictionary and update the value of one key. Display the updated dictionary.

student = {
    "name": "Siva",
    "age": 24
}

student["age"] = 25

print(student)

# %%
# Q25.
# Create a dictionary:
# {
# "name":"Test",
# "age":24,
# "city":"Chennai"
# }
# Remove the city key and display the updated dictionary.

student = {
    "name": "Siva",
    "age": 24,
    "course": "Python"
}

print(student["name"])

# %%
# Q26.

# Create a dictionary containing 5 students and their marks. Display all student names.

students = {
    "Sanjana": 85,
    "Priya": 90,
    "Riya": 78,
    "Anjali": 88,
    "Pooja": 92
}

print("Student Names:")
for name in students.keys():
    print(name)

# %%
# Q27.
# Create a dictionary of products and prices. Search for a product and display its price.

products = {
    "Laptop": 50000,
    "Mobile": 20000,
    "Tablet": 15000,
    "Mouse": 500
}

product = input("Enter product name: ")

if product in products:
    print("Price:", products[product])
else:
    print("Product not found")

# %%
# Q28.
# Check whether a given key exists in a dictionary or not.

student = {
    "name": "Siva",
    "age": 24,
    "course": "Python"
}

key = input("Enter key to search: ")

if key in student:
    print("Key exists in the dictionary")
else:
    print("Key does not exist in the dictionary")

# %%
# Q29.
# Store 5 student names in a list and convert that list into a tuple.

students = ["Sanjana", "Priya", "Riya", "Anjali", "Pooja"]

student_tuple = tuple(students)

print("List:", students)
print("Tuple:", student_tuple)

# %%
# Q30.
# Create a dictionary where:
# - Key = Student Name
# - Value = Marks
# Display all students who scored more than 80 marks.

students = {
    "Sanjana": 85,
    "Priya": 90,
    "Riya": 78,
    "Anjali": 88,
    "Pooja": 75
}

print("Students who scored more than 80 marks:")

for name, marks in students.items():
    if marks > 80:
        print(name, "-", marks)
